# %% [markdown]
# <a href="https://colab.research.google.com/github/Shuja1401/BuildingBlocks/blob/main/Quiz.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import sys
questions=[]
#MAIN Menu: This function let's you build a quiz or pay it.
def main_menu():
  while True:
    print("------Main Menu------")
    print("1. Play Quiz")
    print("2. Edit Questions")
    print("3. Exit")
    try:
      choice=int(input())
    except ValueError:
      print("Invalid input. Please enter a number.")
      continue
    if choice==1:
      play()
    elif choice==2:
      build_quiz()
    elif choice==3:
      return
    else:
      print("Enter a value between 1 and 3.")
#-----------------------------------------------------------------------------------------

#This function let's a user add/delete/display quiz questions.
def build_quiz():
  while True:
    print("--------Enter your choice--------")
    print("1. I want to delete a question.")
    print("2. I want to add a question.")
    print("3. I want to edit a question")
    print("4. I want to list all questions")
    print("5. I want to exit the quiz.")
    try:
      edit_choice=int(input("Enter your choice:"))
    except ValueError:
      print("Invalid input. Please enter a number.")
      continue
    if edit_choice==1:
      del_question()
      continue
    elif edit_choice==2:
      add_question()
      continue
    elif edit_choice==3:
      edit_question()
      continue
    elif edit_choice==4:
      show_questions()
      continue
    elif edit_choice==5:
      return
    else:
      print("Invalid input. Please enter a number between 1 and 5.")
#-----------------------------------------------------------------------------------------------------------

#This function helps user navigate the quiz flow at the end of a response.
def navigate():
  while True:
    print("Do you want to cotinue(c)/exit(x)/Return to Main Menu(m)?")
    cont=input().lower()
    if cont=='c': return 'continue'
    elif cont=='x': return 'exit'
    elif cont=='m': main_menu()
    else: print("Invalid input. Please enter 'c', 'x', or 'm'.")
#------------------------------------------------------------------------------------------------------------

#This function displays all the quiz questions.
def show_questions():
  print("------LIST OF QUESTIONS------")
  for i in range(len(questions)):
    print(f"Question number:{i+1}: {questions[i]['Question']}")
    print(f"A. {questions[i]['A']}")
    print(f"B. {questions[i]['B']}")
    print(f"C. {questions[i]['C']}")
    print(f"Correct answer (Enter value from 1-3): {questions[i]['correct_answer']}")
#-----------------------------------------------------------------------------------------------------------

#This function let's the user add a new quiz question.
def add_question():
  while True:
    print("--------Add Question--------")
    QuestionNo=len(questions)+1
    print("Enter the question")
    Question=input()
    print("Enter option 1:")
    A=input()
    print("Enter option 2:")
    B=input()
    print("Enter option 3:")
    C=input()
    print("Enter the correct answer:")
    correct_answer=int(input())
    questions.append({"Question":Question, "A": A, "B": B, "C":C, "correct_answer":correct_answer})
    print("Question added successfully!")
    choice=navigate()
    if choice=='continue':
      continue
    elif choice=='exit':
      return
    else:
      break
#-----------------------------------------------------------------------------------------------------------

#This function let's a user delete a quiz question.
def del_question(qdel=None):
  if qdel is None:
    while True:
      print("------DELETE A QUESTION------")
      try:
        qdel=int(input("Enter the question number that you want to delete:"))
      except ValueError:
        print("Incorrect value.")
      if 1<=qdel<=len(questions):
        del questions[qdel-1]
        print("Deletion successful")
      else:
        print(f"Enter value within 1 and {len(questions)}")
      choice=navigate()
      if choice=='continue':
        continue
      elif choice=='exit':
        return
      else:
        break
  else:
    del questions[qdel-1]
    print("Deletion successful")
#-----------------------------------------------------------------------------------------------------------

#This function let's a user edit a quiz question. It asks the user for the question number to edit. It deletes it by calling delete function and then asks user to add a new function by calling the add() function.
def edit_question():
  print("------EDIT A QUESTION------")
  try:
    qedit=int(input("Enter the question number that you want to edit:"))
    print("Question will be removed and a new question will be added.")
    del_question(qedit)
    add_question()
  except ValueError:
    print("Incorrect value.")
    return questions
#-----------------------------------------------------------------------------------------------------------

#This function let's a user play the quiz.
def play():
  while True:
    print("GET.SET.GO!")
    print("When ready, press enter!")
    input()
    score=0
    for i in range(len(questions)):
      print(f"Q{i+1}. {questions[i]['Question']}")
      print(f"A. {questions[i]['A']}")
      print(f"B. {questions[i]['B']}")
      print(f"C. {questions[i]['C']}")
      try:
        answer=input("Enter your answer (Enter value from 1-3 or press space to pass):").strip()
      except:
        print("Invalid input. Please enter a number between 1 and 3.")
        continue
      if answer.isdigit() and answer==questions[i]['correct_answer']:
        score=score+1
      elif answer==" ":
        continue
      else:
        score=score-1
    print(f"Your score is:{score}")
    choice=navigate()
    if choice=='continue':
      continue
    elif choice=='exit':
      return
    else:
      break
#-------------------------------------------------------------------------------------------------------

#Main code block
main_menu()
# Out:
# ------Main Menu------
# 1. Play Quiz
# 2. Edit Questions
# 3. Exit
# 2
# --------Enter your choice--------
# 1. I want to delete a question.
# 2. I want to add a question.
# 3. I want to edit a question
# 4. I want to list all questions
# 5. I want to exit the quiz.
# Enter your choice:2
# --------Add Question--------
# Enter the question
# What
# Enter option 1:
# A
# Enter option 2:
# B
# Enter option 3:
# C
# Enter the correct answer:
# 1
# Question added successfully!
# Do you want to cotinue(c)/exit(x)/Return to Main Menu(m)?
# c
# --------Add Question--------
# Enter the question
# Where
# Enter option 1:
# A
# Enter option 2:
# B
# Enter option 3:
# C
# Enter the correct answer:
# 2
# Question added successfully!
# Do you want to cotinue(c)/exit(x)/Return to Main Menu(m)?
# c
# --------Add Question--------
# Enter the question
# When
# Enter option 1:
# A
# Enter option 2:
# B
# Enter option 3:
# C
# Enter the correct answer:
# 3
# Question added successfully!
# Do you want to cotinue(c)/exit(x)/Return to Main Menu(m)?
# c
# --------Add Question--------
# Enter the question
# Which
# Enter option 1:
# A
# Enter option 2:
# B
# Enter option 3:
# C
# Enter the correct answer:
# 3
# Question added successfully!
# Do you want to cotinue(c)/exit(x)/Return to Main Menu(m)?
# c
# --------Add Question--------
# Enter the question
# How many
# Enter option 1:
# A
# Enter option 2:
# B
# Enter option 3:
# C
# Enter the correct answer:
# 2
# Question added successfully!
# Do you want to cotinue(c)/exit(x)/Return to Main Menu(m)?
# m
# ------Main Menu------
# 1. Play Quiz
# 2. Edit Questions
# 3. Exit
# 1
# GET.SET.GO!
# When ready, press enter!
#
# Q1. What
# A. A
# B. B
# C. C
# Enter your answer (Enter value from 1-3 or press space to pass):1
# Q2. Where
# A. A
# B. B
# C. C
# Enter your answer (Enter value from 1-3 or press space to pass):1
# Q3. When
# A. A
# B. B
# C. C
# Enter your answer (Enter value from 1-3 or press space to pass):1
# Q4. Which
# A. A
# B. B
# C. C
# Enter your answer (Enter value from 1-3 or press space to pass):1
# Q5. How many
# A. A
# B. B
# C. C
# Enter your answer (Enter value from 1-3 or press space to pass):1
# Your score is:-5
# Do you want to cotinue(c)/exit(x)/Return to Main Menu(m)?

# %%
# Out:
# {}
